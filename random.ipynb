# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
import polars as pl

pd.set_option('display.float_format', lambda x: f'{x :.2f}')
from get_dataframes import GetDataframes
import hjson

import matplotlib.pyplot as plt
import explo_data_analysis.eda_movies as eda

with open("config.hjson") as fp:
    config = hjson.load(fp)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
actors = "clean_datasets/actors_movies.parquet"

df = pd.read_parquet(actors)

# %%
col_to_keep = [
    "titre_id",
    "titre_str",
    "titre_genres",
    "rating_avg",
    "rating_votes",
    "person_name",
    "person_film"
]# pour chaque id de film recuperer tous les acteurs et mettre dans liste pour nouvlle df stars
# pour chaque id de film recuperer tous les directors et mettre dans liste pour nouvlle df directors

# %%
df
# Out:
#         titre_id        titre_str  titre_date_sortie  titre_duree  \
# 0      tt0093191  Wings of Desire               1987          128
# 1      tt0093191  Wings of Desire               1987          128
# 2      tt0093191  Wings of Desire               1987          128
# 3      tt0093191  Wings of Desire               1987          128
# 4      tt0057643  The Executioner               1963           87
# ...          ...              ...                ...          ...
# 31102  tt8267604        Capernaum               2018          126
# 31103  tt4028464    The Innocents               2021          117
# 31104  tt4028464    The Innocents               2021          117
# 31105  tt4028464    The Innocents               2021          117
# 31106  tt4028464    The Innocents               2021          117
#
#                     titre_genres  rating_avg  rating_votes original_language  \
# 0      [Drama, Fantasy, Romance]        7.90         74953                de
# ...

# %%
df = df[col_to_keep]

df.loc[:, "person_name"] = df["person_name"].str.split(", ")

# %%
df
# Out:
#         titre_id        titre_str               titre_genres  rating_avg  \
# 0      tt0093191  Wings of Desire  [Drama, Fantasy, Romance]        7.90
# 1      tt0093191  Wings of Desire  [Drama, Fantasy, Romance]        7.90
# 2      tt0093191  Wings of Desire  [Drama, Fantasy, Romance]        7.90
# 3      tt0093191  Wings of Desire  [Drama, Fantasy, Romance]        7.90
# 4      tt0057643  The Executioner            [Comedy, Drama]        7.90
# ...          ...              ...                        ...         ...
# 31102  tt8267604        Capernaum                    [Drama]        8.40
# 31103  tt4028464    The Innocents   [Drama, Fantasy, Horror]        7.00
# 31104  tt4028464    The Innocents   [Drama, Fantasy, Horror]        7.00
# 31105  tt4028464    The Innocents   [Drama, Fantasy, Horror]        7.00
# 31106  tt4028464    The Innocents   [Drama, Fantasy, Horror]        7.00
#
#        rating_votes                      person_name  \
# ...

# %%
person_name = df.groupby("titre_id")["person_name"].sum().reset_index()
person_list = person_name["person_name"].to_list()

# %%
person_list

# %%
import pandas as pd

# %%
def import_csv(url: str, sep):
    return pd.read_csv(url, sep=sep)

# %%
df = import_csv("testing/mika.csv")

# %%
df["CA"] = df["quantite_commande"] * df["quantite_expedie"]

# %%
df
# Out:
#       depot           numero_commande  reference_produit  \
# 0   Croissy  CO2309-1500 - 6100632709            8108727
# 1   Croissy  CO2309-1500 - 6100632709            8108726
# 2   Croissy  CO2309-1500 - 6100632709            8108725
# 3   Croissy  CO2309-1500 - 6100632709            8108724
# 4   Croissy  CO2310-1579 - 6100634511            8104045
# 5   Croissy  CO2310-1579 - 6100634511            8106002
# 6   Croissy  CO2310-1579 - 6100634511            8104046
# 7   Croissy  CO2310-1598 - 6100634883            8106002
# 8   Croissy  CO2310-1598 - 6100634883            8106005
# 9   Croissy  CO2310-1598 - 6100634883            8106003
# 10  Croissy  CO2310-1598 - 6100634883            8106004
# 11  Croissy  CO2310-1608 - 6100634995            8104044
# 12  Croissy  CO2310-1608 - 6100634995            8104045
# 13  Croissy  CO2310-1608 - 6100634995            8104046
# 14  Croissy  CO2310-1608 - 6100634995            8104047
# ...
